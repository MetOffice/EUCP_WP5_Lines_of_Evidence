# %%
# imports
import iris
import iris.coord_categorisation as iccat
from iris.experimental import equalise_cubes

import glob
import re
import os

# %%
# folder of files to process
file_path = '_cp-rcm/ICTP-RegCM/ALP-3/HadGEM/historical/r1i1p1/ICTP-RegCM4-7-0/v0/1hr/pr/pr*.nc'
freq = 'day'

# %%
# function to fix any rounding issues with coord systems
# needed for _HCLIMcom/ICHEC-EC-EARTH/rcp85
def fix_coord_metadata(cube):
    for c in ['projection_x_coordinate', 'projection_y_coordinate']:
        cube.coord(c).coord_system.false_easting = round(cube.coord(c).coord_system.false_easting, 9)
        cube.coord(c).coord_system.false_northing = round(cube.coord(c).coord_system.false_northing, 9)

# %%
# load data
# in operations loop over each file individually

# glob the file_path and process each file individually
files = glob.glob(file_path)

cubes = iris.load(f'{files[0]}', ['pr', 'tas'])
# Out:
# /opt/conda/lib/python3.7/site-packages/iris/coord_systems.py:180: RuntimeWarning: divide by zero encountered in double_scalars
#   semi_minor_axis = semi_major_axis - ((1.0 / inverse_flattening) *

# %%
# check and fix rounding issue in metadata for lambert coords
if len(cubes[0].coords("projection_x_coordinate")) > 0:
    for c in cubes:
        fix_coord_metadata(c)

# concatenate and add required coords for processing
equalise_cubes.equalise_attributes(cubes)
cube = cubes.concatenate_cube()

# check last two time points, if from a different month, subtract half an hour to fix
if cube.coord('time').cell(-2).point.month != cube.coord('time').cell(-1).point.month:
    # check time units is what we expect
    unit = cube.coord('time').units
    if unit.name[:4] == 'hour':
        thirty_mins = 0.5
    elif unit.name[:6] == 'second':
        thirty_mins = 60 * 30
    elif unit.name[:3] == 'day':
        thirty_mins = 0.5 / 24
    else:
        raise ValueError(f"Don't know how to deal with: '{unit.name}'")

    print('Subtracting half an hour from time coord first')
    new_points = cube.coord('time').points - thirty_mins
    cube.coord('time').points = new_points

# %%
iccat.add_year(cube, 'time')
if freq == 'mon':
    iccat.add_month_number(cube, 'time')
    agg_by = ['month_number', 'year']
    remove_later = 'month_number'
elif freq == 'day':
    iccat.add_day_of_year(cube, 'time')
    agg_by = ['day_of_year', 'year']
    remove_later = 'day_of_year'
else:
    raise ValueError('Unrecognised frequency')

# %%
# compute averages
print(f'Computing {freq} average')
means = cube.aggregated_by(agg_by, iris.analysis.MEAN)
# Out:
# Computing day average

# %%
# remove no longer needed aux coords
means.remove_coord(remove_later)
means.remove_coord('year')

# %%
# make sure standard names are being used
if means.var_name == 'pr':
    means.standard_name = 'precipitation_flux'
if means.var_name == 'tas':
    means.standard_name = 'air_temperature'

# save
# construct new filename
# need to compute start and end month of file
if freq == 'mon':
    file_start = f'{means.coord("time").cell(0).point.year}{means.coord("time").cell(0).point.month:02}'
    file_end = f'{means.coord("time").cell(-1).point.year}{means.coord("time").cell(-1).point.month:02}'
else:
    file_start = f'{means.coord("time").cell(0).point.year}{means.coord("time").cell(0).point.month:02}{means.coord("time").cell(0).point.day:02}'
    file_end = f'{means.coord("time").cell(-1).point.year}{means.coord("time").cell(-1).point.month:02}{means.coord("time").cell(-1).point.day:02}'

# do appropriate replacements
file_template = files[0]
file_template = re.sub(r'\/1hr\/', f'/{freq}/', file_template)
file_template = re.sub(r'_1hr_', f'_{freq}_', file_template)
if re.search(r'\d{12}-\d{12}.nc', file_template):
    file_template = re.sub(r'\d{12}-\d{12}.nc', f'{file_start}-{file_end}.nc', file_template)
elif re.search(r'\d{10}-\d{10}.nc', file_template):
    file_template = re.sub(r'\d{10}-\d{10}.nc', f'{file_start}-{file_end}.nc', file_template)
elif re.search(r'\d{4}_\d{4}.nc', file_template):
    file_template = re.sub(r'\d{4}_\d{4}.nc', f'{file_start}-{file_end}.nc', file_template)
else:
    raise ValueError("Couldn't match date strings in filename")

out_file = file_template

# make output folder if necessary
out_dir, fname = os.path.split(out_file)
out_dir = f"ALP-3_{freq}_means/{out_dir.split('/', 1)[1]}"
os.makedirs(out_dir, exist_ok=True)

out_path = os.path.join(out_dir, fname)

# %%
# save
print(f'Saving to: {out_path}')
iris.save(means, out_path)
# Out:
# Saving to: ALP-3_day_means/ICTP-RegCM/ALP-3/HadGEM/historical/r1i1p1/ICTP-RegCM4-7-0/v0/day/pr/pr_ALP-3_HadGEM_historical_r1i1p1_ICTP-RegCM4-7-0_v0_day_19950401-19950430.nc

# %%
print(files[0])
print(means)
# Out:
# _cp-rcm/ICTP-RegCM/ALP-3/HadGEM/historical/r1i1p1/ICTP-RegCM4-7-0/v0/1hr/pr/pr_ALP-3_HadGEM_historical_r1i1p1_ICTP-RegCM4-7-0_v0_1hr_1995040100-1995050100.nc
# precipitation_flux / (kg m-2 s-1)   (time: 30; projection_y_coordinate: 572; projection_x_coordinate: 602)
#      Dimension coordinates:
#           time                           x                            -                             -
#           projection_y_coordinate        -                            x                             -
#           projection_x_coordinate        -                            -                             x
#      Auxiliary coordinates:
#           latitude                       -                            x                             x
#           longitude                      -                            x                             x
#      Attributes:
#           CDI: Climate Data Interface version 1.9.8rc1 (http://mpimet.mpg.de/cdi)
#           CDO: Climate Data Operators version 1.9.8rc1 (http://mpimet.mpg.de/cdo)
#           CORDEX_domain: ALP-3
#           Conventions: CF-1.7
#           ICTP_version_note: none
#           absorption_emission_time_step_in_seconds: 64800.0
#           asselin_filter_nu_1: 0.1
#           asselin_filter_nu_2: 0.1
#           atmosphere_time_step_in_seconds: 9.0
#           background_diffusion_coefficient: 1.0
#           base_state_surface_temperature: 283.19046819040614
#           boundary_dm: -1.0
#           boundary_high_nudge: 9.0
#           boundary_layer_scheme: 1
#           boundary_low_nudge: 3.0
#           boundary_medium_nudge: 6.0
#           boundary_nm: -1.0
#           boundary_nspgd: 30
#           boundary_nspgx: 30
#           chemical_aerosol_scheme_activated: 0
#           climatic_aerosol_input_dataset: 0
#           climatic_ozone_input_dataset: 0
#           cloud_arctic_cloud_correction: Yes
#           cloud_bottom_level_with_no_clouds: 1
#           cloud_cloud_fraction_max_for_convection: 1.0
#           cloud_cloud_fraction_maximum: 0.75
#           cloud_cloud_liqwat_max_for_convection: 0.0003
#           cloud_condensation_threshold: 1.0
#           cloud_deep_convective_cf_param: 0.14
#           cloud_extreme_gradient_fraction: 0.5
#           cloud_k2_convective_cf_param: 500.0
#           cloud_rh1_limit_temperature: 238.0
#           cloud_rh_threshold_for_land: 0.8
#           cloud_rh_threshold_for_ocean: 0.9
#           cloud_rh_with_fcc_one: 1.01
#           cloud_shallow_convective_cf_param: 0.07
#           cloud_surface_radiation_hack: No
#           comment: RegCM CORDEX alps_cp3km run
#           contact: esp@ictp.it
#           convection_time_step_in_seconds: 288.0
#           convective_lwp_as_large_scale: 1
#           creation_date: 2020-06-16T21:45:56Z
#           cumulus_cloud_model: 1
#           cumulus_convection_scheme_lnd: 5
#           cumulus_convection_scheme_ocn: 5
#           diffusion_hgt_factor: 0
#           diurnal_cycle_sst_scheme: 0
#           driving_experiment: HadGEM, rcp85, r1i1p1
#           driving_experiment_name: rcp85
#           driving_model_ensemble_member: r1i1p1
#           driving_model_id: HadGEM
#           dynamical_core: 2
#           dynamical_diffusion_coefficient: 1.0
#           experiment: ALP-3
#           experiment_id: rcp85
#           fix_solar_parameters: 0
#           frequency: 1hr
#           grid_factor: 0.7013462245828468
#           grid_size_in_meters: 3000.0
#           history: Wed Jun 17 17:44:51 2020: cdo -f nc4 -z zip -mergetime output/ALP-3/ICTP/HadGEM/rcp85/r1i1p1/ICTP-RegCM4-7-0/v0/1hr/pr/pr_ALP-3_HadGEM_rcp85_r1i1p1_ICTP-RegCM4-7-0_v0_1hr_1995040100-1995040200.nc...
#           holtslag_critical_land_richardson: 0.25
#           holtslag_critical_ocean_richardson: 0.25
#           holtslag_th10_estimate: 1
#           holtslag_th10_maximize: 1
#           holtslag_th10_niteration: 1
#           holtslag_zhnew_factor: 0.25
#           institute_id: ICTP
#           institution: International Centre for Theoretical Physics
#           ipcc_scenario_code: RCP85
#           lake_model_activated: 1
#           landsurface_model: clm4.5
#           large_scale_cloud_fraction_scheme: 0
#           lateral_boundary_condition_scheme: 5
#           latitude_of_projection_origin: 45.441
#           logp_lapse_rate: 47.7
#           longitude_of_projection_origin: 8.062
#           model_icbc_data_source: FNEST
#           model_id: ICTP-RegCM4-7-0
#           model_is_restarted: Yes
#           model_revision: tag-4.7.0
#           model_simulation_end:  2006-01-01 00:00:00 UTC
#           model_simulation_initial_start:  1995-01-01 00:00:00 UTC
#           model_simulation_start:  1995-02-22 00:00:00 UTC
#           model_sst_data_source: HA_85
#           moisture_scheme: 3
#           note: The domain is larger than ALP-3
#           ocean_albedo_from_whitecapping: 0
#           ocean_flux_scheme: 2
#           ocean_precipitaion_cooling_effect: 0
#           ocean_stratiform_clouds_scheme: 1
#           off_centering_max: 0.25
#           product: output
#           project_id: CORDEX
#           projection: LAMCON
#           radiation_scheme_time_step_in_seconds: 1800.0
#           rayleigh_alpha0: 0.001
#           rayleigh_damping: 1
#           rayleigh_hd: 10000.0
#           rayleigh_ndamp: 5
#           rayleigh_zetad: 15452.44042882886
#           rcm_version_id: v0
#           references: http://gforge.ictp.it/gf/project/regcm
#           rrtm_radiation_scheme_activated: 0
#           seasonal_desert_albedo: 0
#           semi_lagrangian_advection_scheme: 0
#           simple_sea_ice_scheme: 0
#           sound_bet_param: 0.4
#           sound_xkd_param: 0.1
#           source: RegCM Model output file
#           stability_enhance: Yes
#           standard_parallel: [41. 48.]
#           static_solar_constant_used: 0
#           sun_year_offset: 0.0
#           surface_emissivity_factor_computed: 0
#           surface_interaction_time_step_in_seconds: 450.0
#           temperature_extreme_gradient: 5.0
#           tiedtke_actual_scheme: 4
#           tiedtke_cape_adjustment_timescale: 3600.0
#           tiedtke_cloud_cover_evap_over_land: 0.05
#           tiedtke_cloud_cover_evap_over_ocean: 0.05
#           tiedtke_cloud_water_conv_over_land: 0.0014
#           tiedtke_cloud_water_conv_over_ocean: 0.0014
#           tiedtke_coeff_evap_over_land: 5.55e-05
#           tiedtke_coeff_evap_over_ocean: 5.55e-05
#           tiedtke_critical_rh_over_land: 0.7
#           tiedtke_critical_rh_over_ocean: 0.9
#           tiedtke_cumulus_downdraft: No
#           tiedtke_cumulus_friction: No
#           tiedtke_detrainment_rate_deep_land: 7.5e-05
#           tiedtke_detrainment_rate_deep_ocean: 7.5e-05
#           tiedtke_entrainment_rate_deep_land: 0.00175
#           tiedtke_entrainment_rate_deep_ocean: 0.00175
#           tiedtke_entrainment_rate_downdraft: 0.0003
#           tiedtke_ke_dissipation: Yes
#           tiedtke_midlevel: No
#           tiedtke_penetrative: No
#           tiedtke_prognostic_cloud: No
#           tiedtke_shallow: Yes
#           tiedtke_shallow_entrainment: 2.0
#           tiedtke_shallow_wstar_closure: Yes
#           tiedtke_tracer_smooth_massflux: Yes
#           tiedtke_tracer_transport: Yes
#           title: ICTP Regional Climatic model V4
#           top_nudging: 0
#           tracer_extreme_gradient_fraction: 0.5
#           tracking_id: fec9362e-b009-11ea-9d18-0894ef2450dd
#           upper_radiative_bc: 1
#           upstream_mode: Yes
#           vapor_extreme_gradient_fraction: 0.2
#           zeng_ocean_roughness_formula: 1
#           zeng_ocean_roughness_method: 1
#      Cell methods:
#           mean: time
#           mean: day_of_year, year
